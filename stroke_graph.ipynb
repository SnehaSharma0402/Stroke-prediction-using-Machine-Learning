# %%
import numpy as np
import pandas as pd
data=r"C:\Users\DELL\OneDrive\Documents\Documents\Project\project 2\New folder\smote.csv"
df=pd.read_csv(data)
df
# Out:
#          id  gender        age  hypertension  heart_disease  ever_married  \
# 0     61350       1  20.000000             0              0             0
# 1     56556       1  60.339594             0              1             1
# 2     57618       0  47.000000             0              0             1
# 3     21292       1  38.000000             0              0             1
# 4      5509       0  77.251641             0              0             1
# ...     ...     ...        ...           ...            ...           ...
# 9717   7970       1  59.539346             1              0             1
# 9718  43676       0  59.868898             0              0             1
# 9719  32606       0  80.456099             0              0             1
# 9720  42203       1  59.000000             0              0             1
# 9721  13666       1  72.564338             0              0             0
#
#       avg_glucose_level        bmi  work_type_freq  Residence_type_freq  \
# ...

# %%
df.shape
# Out:
# (9722, 12)

# %%
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# avg_glucose_level      0
# bmi                    0
# work_type_freq         0
# Residence_type_freq    0
# smoking_status_freq    0
# stroke                 0
# dtype: int64

# %%
# Count the occurrences of each value (0 and 1) in the 'stroke' column
stroke_counts = df['stroke'].value_counts()

# Print the counts
print(stroke_counts)
# Out:
# stroke
# 0    4861
# 1    4861
# Name: count, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
corr = df.corr()

# Plot the heatmap
plt.figure(figsize=(8, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.countplot(x='stroke', data=df)
plt.title('Count of Stroke Cases')
plt.show()

# %%
age_group = df.groupby('age')['stroke'].mean().reset_index()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(age_group['age'], age_group['stroke'], marker='o', linestyle='-')
plt.title('Age-wise Stroke Prevalence')
plt.xlabel('Age')
plt.ylabel('Stroke Prevalence')
plt.grid(True)
plt.show()

# %%
bins = [0, 30, 40, 50, 60, 70, 80, 90]
labels = ['0-30', '31-40', '41-50', '51-60', '61-70', '71-80', '81-90']

# Create a new column for age bins
df['age_bin'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

# Group by age bins and calculate stroke prevalence
age_bin_group = df.groupby('age_bin')['stroke'].mean().reset_index()

# Plotting
plt.figure(figsize=(8, 6))
plt.bar(age_bin_group['age_bin'], age_bin_group['stroke'], color='orange')
plt.title('Stroke Prevalence by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Stroke Prevalence')
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18968\3409302745.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_bin_group = df.groupby('age_bin')['stroke'].mean().reset_index()

# %%
df['age_bin'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

# Group by age bins and calculate stroke prevalence
age_bin_group = df.groupby('age_bin')['stroke'].mean().reset_index()

# Plotting
plt.figure(figsize=(8, 6))
plt.bar(age_bin_group['age_bin'], age_bin_group['stroke'], color='orange')
plt.title('Stroke Prevalence by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Stroke Prevalence')

# Remove borders
ax = plt.gca()  # Get current axis
for spine in ax.spines.values():
    spine.set_visible(False)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18968\473081791.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_bin_group = df.groupby('age_bin')['stroke'].mean().reset_index()

# %%
# Define age bins and labels
bins = [0, 30, 40, 50, 60, 70, 80, 90]
labels = ['0-30', '31-40', '41-50', '51-60', '61-70', '71-80', '81-90']

# Create a new column for age bins
df['age_bin'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

# Group by age bins and calculate stroke prevalence
age_bin_group = df.groupby('age_bin')['stroke'].mean().reset_index()

# Plotting
plt.figure(figsize=(8, 6))
plt.bar(age_bin_group['age_bin'], age_bin_group['stroke'], color='orange')
plt.title('Stroke Prevalence by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Stroke Prevalence')

# Remove borders
ax = plt.gca()  # Get current axis
for spine in ax.spines.values():
    spine.set_visible(False)

# Set y-axis limit
plt.ylim(0, 0.9)

# Add grid for y-axis
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18968\3070804879.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_bin_group = df.groupby('age_bin')['stroke'].mean().reset_index()

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['age'], bins=30, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
age_bin_stroke = df.groupby('age_bin')['stroke'].value_counts().unstack().fillna(0)
age_bin_stroke.plot(kind='bar', stacked=True, figsize=(10, 6), color=['skyblue', 'salmon'])
plt.title('Stroke Count by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.legend(['No Stroke', 'Stroke'])
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18968\2250316737.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_bin_stroke = df.groupby('age_bin')['stroke'].value_counts().unstack().fillna(0)

# %%
# Group by age_bin and stroke status, and compute counts
age_bin_stroke = df.groupby('age_bin')['stroke'].value_counts().unstack().fillna(0)

# Plotting
plt.figure(figsize=(10, 6))
ax = age_bin_stroke.plot(kind='bar', stacked=True, color=['skyblue', 'salmon'])

# Customize plot
plt.title('Stroke Count by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.legend(['No Stroke', 'Stroke'])
plt.grid(axis='y')

# Set y-axis limit to 3000
ax.set_ylim(0, 3000)

# Remove plot borders
for spine in ax.spines.values():
    spine.set_visible(False)

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18968\397448554.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_bin_stroke = df.groupby('age_bin')['stroke'].value_counts().unstack().fillna(0)

# %%
gender_stroke = df.groupby('gender')['stroke'].value_counts().unstack().fillna(0)

# Plotting
plt.figure(figsize=(10, 6))
gender_stroke.plot(kind='bar', stacked=True, color=['skyblue', 'salmon'])
plt.title('Stroke Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(['No Stroke', 'Stroke'])
plt.grid(axis='y')
plt.show()

# %%
df['gender'] = df['gender'].map({1: 'Male', 0: 'Female'})

# Group by gender and stroke status
gender_stroke = df.groupby('gender')['stroke'].value_counts().unstack().fillna(0)

# Plotting
plt.figure(figsize=(10, 6))
gender_stroke.plot(kind='bar', stacked=True, color=['skyblue', 'salmon'])
plt.title('Stroke Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(['No Stroke', 'Stroke'])
plt.grid(axis='y')
plt.show()

# %%
sns.pairplot(df, hue='stroke', diag_kind='kde', palette='coolwarm')
plt.title('Pair Plot of Numerical Features by Stroke Status')
plt.show()
# Out:
# C:\Users\DELL\.anaconda\anaco\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\.anaconda\anaco\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\.anaconda\anaco\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
print(df[['gender', 'stroke']].head())
print(df['gender'].value_counts())
print(df['stroke'].value_counts())
# Out:
#   gender  stroke
# 0    NaN       0
# 1    NaN       1
# 2    NaN       0
# 3    NaN       0
# 4    NaN       1
# Series([], Name: count, dtype: int64)
# stroke
# 0    4861
# 1    4861
# Name: count, dtype: int64
